# %%
# !pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.11.2-py3-none-any.whl (292 kB)
#      |████████████████████████████████| 292 kB 3.1 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.15 in /Users/fukushimatakahiro/miniforge3/envs/my_env/lib/python3.8/site-packages (from seaborn) (1.20.3)
# Requirement already satisfied: scipy>=1.0 in /Users/fukushimatakahiro/miniforge3/envs/my_env/lib/python3.8/site-packages (from seaborn) (1.6.3)
# Requirement already satisfied: matplotlib>=2.2 in /Users/fukushimatakahiro/miniforge3/envs/my_env/lib/python3.8/site-packages (from seaborn) (3.4.2)
# Requirement already satisfied: pandas>=0.23 in /Users/fukushimatakahiro/miniforge3/envs/my_env/lib/python3.8/site-packages (from seaborn) (1.2.4)
# Requirement already satisfied: cycler>=0.10 in /Users/fukushimatakahiro/miniforge3/envs/my_env/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (0.10.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/fukushimatakahiro/miniforge3/envs/my_env/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/fukushimatakahiro/miniforge3/envs/my_env/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (2.8.1)
# Requirement already satisfied: pillow>=6.2.0 in /Users/fukushimatakahiro/miniforge3/envs/my_env/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (8.2.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/fukushimatakahiro/miniforge3/envs/my_env/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (1.3.1)
# Requirement already satisfied: six in /Users/fukushimatakahiro/miniforge3/envs/my_env/lib/python3.8/site-packages (from cycler>=0.10->matplotlib>=2.2->seaborn) (1.15.0)
# Requirement already satisfied: pytz>=2017.3 in /Users/fukushimatakahiro/miniforge3/envs/my_env/lib/python3.8/site-packages (from pandas>=0.23->seaborn) (2021.1)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.11.2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import random

# %%
train_df = pd.read_csv("train.csv")
test_df = pd.read_csv("test.csv")
submission = pd.read_csv("gender_submission.csv")

# %%
print("train")
print(train_df.shape)
print("test")
print(test_df.shape)
# Out:
# train
# (891, 12)
# test
# (418, 11)

# %%
print("train")
train_df.head()
# Out:
# train
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
print("test")
test_df.head()
# Out:
# test
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
train_df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
train_df["Sex"].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
train_df["Embarked"].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
train_df["Cabin"].value_counts()
# Out:
# C23 C25 C27    4
# B96 B98        4
# G6             4
# E101           3
# F2             3
#               ..
# D7             1
# B78            1
# C86            1
# A16            1
# A34            1
# Name: Cabin, Length: 147, dtype: int64

# %%
train_df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
test_df.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
plt.style.use("ggplot")

# %%
train_df[["Embarked","Survived","PassengerId"]].dropna()
# Out:
#     Embarked  Survived  PassengerId
# 0          S         0            1
# 1          C         1            2
# 2          S         1            3
# 3          S         1            4
# 4          S         0            5
# ..       ...       ...          ...
# 886        S         0          887
# 887        S         1          888
# 888        S         0          889
# 889        C         1          890
# 890        Q         0          891
#
# [889 rows x 3 columns]

# %%
embarked_df = train_df[["Embarked","Survived","PassengerId"]].dropna().groupby(["Embarked","Survived"]).count().unstack()
embarked_df
# Out:
#          PassengerId
# Survived           0    1
# Embarked
# C                 75   93
# Q                 47   30
# S                427  217

# %%
embarked_df.plot.bar(stacked=True)
# Out:
# <AxesSubplot:xlabel='Embarked'>

# %%
sex_df = train_df[["Sex","Survived","PassengerId"]].dropna().groupby(["Sex","Survived"]).count().unstack()

# %%
sex_df.plot.bar(stacked=True)
# Out:
# <AxesSubplot:xlabel='Sex'>

# %%
ticket_df = train_df[["Pclass","Survived","PassengerId"]].dropna().groupby(["Pclass","Survived"]).count().unstack()

# %%
ticket_df.plot.bar(stacked=True)
# Out:
# <AxesSubplot:xlabel='Pclass'>

# %%
plt.hist((train_df[train_df["Survived"]==0][["Age"]].values, train_df[train_df["Survived"] == 1][["Age"]].values),histtype="barstacked", bins=8, label=("Death","Survive"))
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-534a96a6a30e> in <module>
# ----> 1 plt.hist((train_df[train_df["Survived"]==0][["Age"]].values, train_df[train_df["Survived"] == 1][["Age"]].values),histtype="barstacked", bins=8, label=("Death","Survive"))
#       2 plt.legend()
#
# ~/miniforge3/envs/my_env/lib/python3.8/site-packages/matplotlib/pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    2851         orientation='vertical', rwidth=None, log=False, color=None,
#    2852         label=None, stacked=False, *, data=None, **kwargs):
# -> 2853     return gca().hist(
#    2854         x, bins=bins, range=range, density=density, weights=weights,
#    2855         cumulative=cumulative, bottom=bottom, histtype=histtype,
#
# ~/miniforge3/envs/my_env/lib/python3.8/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1359     def inner(ax, *args, data=None, **kwargs):
#    1360         if data is None:
# -> 1361             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1362
#    1363         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/miniforge3/envs/my_env/lib/python3.8/site-packages/matplotlib/axes/_axes.py in hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6670
#    6671         # Massage 'x' for processing.
# -> 6672         x = cbook._reshape_2D(x, 'x')
#    6673         nx = len(x)  # number of datasets
#    6674
#
# ~/miniforge3/envs/my_env/lib/python3.8/site-packages/matplotlib/cbook/__init__.py in _reshape_2D(X, name)
#    1431         nd = np.ndim(xi)
#    1432         if nd > 1:
# -> 1433             raise ValueError(f'{name} must have 2 or fewer dimensions')
#    1434         result.append(xi.reshape(-1))
#    1435
#
# ValueError: x must have 2 or fewer dimensions

# %%
train_df_corr = pd.get_dummies(train_df,columns=["Sex"],drop_first=True)
train_df_corr = pd.get_dummies(train_df_corr, columns=["Embarked"])

# %%
train_df_corr.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                             Heikkinen, Miss. Laina  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                           Allen, Mr. William Henry  35.0      0      0
#
#              Ticket     Fare Cabin  Sex_male  Embarked_C  Embarked_Q  \
# 0         A/5 21171   7.2500   NaN         1           0           0
# 1          PC 17599  71.2833   C85         0           1           0
# 2  STON/O2. 3101282   7.9250   NaN         0           0           0
# 3            113803  53.1000  C123         0           0           0
# 4            373450   8.0500   NaN         1           0           0
#
#    Embarked_S
# 0           1
# 1           0
# 2           1
# 3           1
# 4           1

# %%
train_corr = train_df_corr.corr()

# %%
train_corr
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
# Sex_male        0.042939 -0.543351  0.131900  0.093254 -0.114631 -0.245489
# Embarked_C     -0.001205  0.168240 -0.243292  0.036261 -0.059528 -0.011069
# Embarked_Q     -0.033606  0.003650  0.221009 -0.022405 -0.026354 -0.081228
# Embarked_S      0.022148 -0.155660  0.081720 -0.032523  0.070941  0.063036
#
#                  Fare  Sex_male  Embarked_C  Embarked_Q  Embarked_S
# PassengerId  0.012658  0.042939   -0.001205   -0.033606    0.022148
# Survived     0.257307 -0.543351    0.168240    0.003650   -0.155660
# Pclass      -0.549500  0.131900   -0.243292    0.221009    0.081720
# Age          0.096067  0.093254    0.036261   -0.022405   -0.032523
# SibSp        0.159651 -0.114631   -0.059528   -0.026354    0.070941
# Parch        0.216225 -0.245489   -0.011069   -0.081228    0.063036
# Fare         1.000000 -0.182333    0.269335   -0.117216   -0.166603
# Sex_male    -0.182333  1.000000   -0.082853   -0.074115    0.125722
# Embarked_C   0.269335 -0.082853    1.000000   -0.148258   -0.778359
# Embarked_Q  -0.117216 -0.074115   -0.148258    1.000000   -0.496624
# Embarked_S  -0.166603  0.125722   -0.778359   -0.496624    1.000000

# %%
plt.figure(figsize=(9,9))
sns.heatmap(train_corr, vmax=1, vmin=-1, center=0,annot=True)
# Out:
# <AxesSubplot:>
